# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\sanch\\OneDrive\\Desktop\\flight-delay-intelligence\\data\\raw\\flights_data.csv")

# %%
df.head(5)
# Out:
#     Used Date From   To   Airline Scheduled Departure  SDEP Departure   DEP  \
# 0  31-01-2020  DEL  HYD  Air Asia                6:05   605      6:04   604
# 1  31-01-2020  DEL  HYD    Indigo                4:50   450      4:36   436
# 2  30-01-2020  DEL  HYD  Air Asia                6:05   605      5:54   554
# 3  30-01-2020  DEL  HYD  Air Asia               17:40  1740     17:40  1740
# 4  30-01-2020  DEL  HYD  Air Asia               19:50  1950     19:54  1954
#
#   Scheduled Arrival  SARR  ... Market Share  OTP Index  \
# 0              8:15   815  ...          5.3       85.6
# 1              7:00   700  ...         47.5       81.1
# 2              8:15   815  ...          5.3       85.6
# 3             19:55  1955  ...          5.3       85.6
# 4             22:10  2210  ...          5.3       85.6
#
#    weather__hourly__windspeedKmph  weather__hourly__weatherDesc__value  \
# 0                              11                        Partly cloudy
# ...

# %%
df.shape
# Out:
# (10718, 29)

# %%
df.columns
# Out:
# Index(['Used Date', 'From', 'To', 'Airline', 'Scheduled Departure', 'SDEP',
#        'Departure', 'DEP', 'Scheduled Arrival', 'SARR', 'Arrival', 'ARR',
#        'Departure Delay', 'Arrival Delay', 'Status', 'Distance',
#        'Passenger Load Factor', 'Airline Rating', 'Airport Rating',
#        'Market Share', 'OTP Index', 'weather__hourly__windspeedKmph',
#        'weather__hourly__weatherDesc__value', 'weather__hourly__precipMM',
#        'weather__hourly__humidity', 'weather__hourly__visibility',
#        'weather__hourly__pressure', 'weather__hourly__cloudcover', 'Category'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of         Used Date From   To   Airline Scheduled Departure  SDEP Departure  \
# 0      31-01-2020  DEL  HYD  Air Asia                6:05   605      6:04
# 1      31-01-2020  DEL  HYD    Indigo                4:50   450      4:36
# 2      30-01-2020  DEL  HYD  Air Asia                6:05   605      5:54
# 3      30-01-2020  DEL  HYD  Air Asia               17:40  1740     17:40
# 4      30-01-2020  DEL  HYD  Air Asia               19:50  1950     19:54
# ...           ...  ...  ...       ...                 ...   ...       ...
# 10713  24-01-2019  CCU  DEL  SpiceJet               18:30  1830     18:30
# 10714  23-01-2019  CCU  DEL  SpiceJet               18:30  1830     18:30
# 10715  22-01-2019  CCU  DEL  SpiceJet               18:30  1830     18:38
# 10716    9/1/2019  DEL  HYD  Spicejet               22:05  2205      0:40
# 10717    2/1/2019  BOM  DEL   Vistara                1:10   110       130
#
# ...

# %%
df.describe()
# Out:
#                SDEP           DEP          SARR           ARR  \
# count  10718.000000  10718.000000  10718.000000  10718.000000
# mean    1347.070349   1331.483486   1320.709461   1260.562605
# std      642.298422    666.186884    704.680126    723.536840
# min        5.000000     -1.000000      5.000000     -1.000000
# 25%      730.000000    726.000000    835.000000    754.250000
# 50%     1320.000000   1259.000000   1245.000000   1220.000000
# 75%     2000.000000   2000.000000   2010.000000   1955.000000
# max     2350.000000   2359.000000   2355.000000   2359.000000
#
#        Departure Delay  Arrival Delay        Status      Distance  \
# count     10718.000000   10718.000000  10718.000000  10718.000000
# mean         26.080892      27.628009      0.992909   1287.418175
# std         126.088783     133.545628      0.083912    319.679362
# min         -60.000000     -61.000000      0.000000    848.000000
# 25%           0.000000      -4.000000      1.000000   1138.000000
# ...

# %%
df.isnull().sum()
# Out:
# Used Date                              0
# From                                   0
# To                                     0
# Airline                                0
# Scheduled Departure                    0
# SDEP                                   0
# Departure                              0
# DEP                                    0
# Scheduled Arrival                      0
# SARR                                   0
# Arrival                                0
# ARR                                    0
# Departure Delay                        0
# Arrival Delay                          0
# Status                                 0
# Distance                               0
# Passenger Load Factor                  0
# Airline Rating                         0
# Airport Rating                         0
# Market Share                           0
# OTP Index                              0
# weather__hourly__windspeedKmph         0
# weather__hourly__weatherDesc__value    0
# ...

# %%
(df==-1).sum()
# Out:
# Used Date                                0
# From                                     0
# To                                       0
# Airline                                  0
# Scheduled Departure                      0
# SDEP                                     0
# Departure                                0
# DEP                                     76
# Scheduled Arrival                        0
# SARR                                     0
# Arrival                                  0
# ARR                                     76
# Departure Delay                        326
# Arrival Delay                          206
# Status                                   0
# Distance                                 0
# Passenger Load Factor                    0
# Airline Rating                           0
# Airport Rating                           0
# Market Share                             0
# OTP Index                                0
# weather__hourly__windspeedKmph           0
# ...

# %%
df.replace(-1, np.nan, inplace=True)

# %%
(df==-1).sum()
# Out:
# Used Date                              0
# From                                   0
# To                                     0
# Airline                                0
# Scheduled Departure                    0
# SDEP                                   0
# Departure                              0
# DEP                                    0
# Scheduled Arrival                      0
# SARR                                   0
# Arrival                                0
# ARR                                    0
# Departure Delay                        0
# Arrival Delay                          0
# Status                                 0
# Distance                               0
# Passenger Load Factor                  0
# Airline Rating                         0
# Airport Rating                         0
# Market Share                           0
# OTP Index                              0
# weather__hourly__windspeedKmph         0
# weather__hourly__weatherDesc__value    0
# ...

# %%
df.describe()
# Out:
#                SDEP           DEP          SARR           ARR  \
# count  10718.000000  10642.000000  10718.000000  10642.000000
# mean    1347.070349   1340.999436   1320.709461   1269.572073
# std      642.298422    658.940894    704.680126    718.189584
# min        5.000000      0.000000      5.000000      0.000000
# 25%      730.000000    730.000000    835.000000    801.000000
# 50%     1320.000000   1304.000000   1245.000000   1224.000000
# 75%     2000.000000   2001.000000   2010.000000   1955.000000
# max     2350.000000   2359.000000   2355.000000   2359.000000
#
#        Departure Delay  Arrival Delay        Status      Distance  \
# count     10392.000000   10512.000000  10718.000000  10718.000000
# mean         26.930427      28.189022      0.992909   1287.418175
# std         127.958727     134.787189      0.083912    319.679362
# min         -60.000000     -61.000000      0.000000    848.000000
# 25%           0.000000      -4.000000      1.000000   1138.000000
# ...

# %%
df[['Departure Delay', 'Arrival Delay']].describe()
# Out:
#        Departure Delay  Arrival Delay
# count     10392.000000   10512.000000
# mean         26.930427      28.189022
# std         127.958727     134.787189
# min         -60.000000     -61.000000
# 25%           0.000000      -4.000000
# 50%           1.000000       4.000000
# 75%          20.000000      25.000000
# max        1440.000000    1440.000000

# %%
df.isnull().sum()
# Out:
# Used Date                                0
# From                                     0
# To                                       0
# Airline                                  0
# Scheduled Departure                      0
# SDEP                                     0
# Departure                                0
# DEP                                     76
# Scheduled Arrival                        0
# SARR                                     0
# Arrival                                  0
# ARR                                     76
# Departure Delay                        326
# Arrival Delay                          206
# Status                                   0
# Distance                                 0
# Passenger Load Factor                    0
# Airline Rating                           0
# Airport Rating                           0
# Market Share                             0
# OTP Index                                0
# weather__hourly__windspeedKmph           0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(10)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Used Date                               object
# From                                    object
# To                                      object
# Airline                                 object
# Scheduled Departure                     object
# SDEP                                     int64
# Departure                               object
# DEP                                    float64
# Scheduled Arrival                       object
# SARR                                     int64
# Arrival                                 object
# ARR                                    float64
# Departure Delay                        float64
# Arrival Delay                          float64
# Status                                   int64
# Distance                                 int64
# Passenger Load Factor                  float64
# Airline Rating                         float64
# Airport Rating                         float64
# Market Share                           float64
# ...

# %%
df['Used Date'] = pd.to_datetime(df['Used Date'], format='mixed')

# %%
df['Used Date'].head()
# Out:
# 0   2020-01-31
# 1   2020-01-31
# 2   2020-01-30
# 3   2020-01-30
# 4   2020-01-30
# Name: Used Date, dtype: datetime64[ns]

# %%
numeric_cols = [
    'Departure Delay',
    'Arrival Delay',
    'Distance',
    'Passenger Load Factor',
    'Airline Rating',
    'Airport Rating',
    'Market Share',
    'OTP Index',
    'weather__hourly__windspeedKmph',
    'weather__hourly__precipMM',
    'weather__hourly__humidity',
    'weather__hourly__visibility',
    'weather__hourly__pressure',
    'weather__hourly__cloudcover'
]

for col in numeric_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
df.dtypes
# Out:
# Used Date                              datetime64[ns]
# From                                           object
# To                                             object
# Airline                                        object
# Scheduled Departure                            object
# SDEP                                            int64
# Departure                                      object
# DEP                                           float64
# Scheduled Arrival                              object
# SARR                                            int64
# Arrival                                        object
# ARR                                           float64
# Departure Delay                               float64
# Arrival Delay                                 float64
# Status                                          int64
# Distance                                        int64
# Passenger Load Factor                         float64
# ...

# %%
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

# %%
categorical_cols = [
    'Airline',
    'From',
    'To',
    'Status',
    'Category',
    'weather__hourly__weatherDesc__value'
]

for col in categorical_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
df.isnull().sum()
# Out:
# Used Date                               0
# From                                    0
# To                                      0
# Airline                                 0
# Scheduled Departure                     0
# SDEP                                    0
# Departure                               0
# DEP                                    74
# Scheduled Arrival                       0
# SARR                                    0
# Arrival                                 0
# ARR                                    74
# Departure Delay                         0
# Arrival Delay                           0
# Status                                  0
# Distance                                0
# Passenger Load Factor                   0
# Airline Rating                          0
# Airport Rating                          0
# Market Share                            0
# OTP Index                               0
# weather__hourly__windspeedKmph          0
# ...

# %%
df[['DEP', 'ARR']].dtypes
# Out:
# DEP    float64
# ARR    float64
# dtype: object

# %%
df[['DEP', 'ARR']] = df[['DEP', 'ARR']].fillna(df[['DEP', 'ARR']].median())

# %%
df.isnull().sum()
# Out:
# Used Date                              0
# From                                   0
# To                                     0
# Airline                                0
# Scheduled Departure                    0
# SDEP                                   0
# Departure                              0
# DEP                                    0
# Scheduled Arrival                      0
# SARR                                   0
# Arrival                                0
# ARR                                    0
# Departure Delay                        0
# Arrival Delay                          0
# Status                                 0
# Distance                               0
# Passenger Load Factor                  0
# Airline Rating                         0
# Airport Rating                         0
# Market Share                           0
# OTP Index                              0
# weather__hourly__windspeedKmph         0
# weather__hourly__weatherDesc__value    0
# ...

# %%
(df == -1).sum().sum()
# Out:
# np.int64(0)

# %%
df.replace("-1", np.nan, inplace=True)

# %%
df.replace(-1, np.nan, inplace=True)

# %%
(df == -1).sum().sum()
# Out:
# np.int64(0)

# %%
(df == "-1").sum().sum()
# Out:
# np.int64(0)

# %%
df.to_csv("C:\\Users\\sanch\\OneDrive\\Desktop\\flight-delay-intelligence\\data\\cleaned\\cleaned_flights.csv", index=False)
